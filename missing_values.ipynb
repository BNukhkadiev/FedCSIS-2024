# %%
from data_loader import *

# %%
training_data.isna().sum()
# Out:
# Group        0
# I1           0
# I2           0
# I3           0
# I4         525
#           ...
# dI56        20
# dI57       135
# dI58       249
# Class        0
# Perform      0
# Length: 119, dtype: int64

# %%
miss = training_data[training_data.isna().any(axis=1)]
miss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2806 entries, 2 to 7999
# Columns: 119 entries, Group to Perform
# dtypes: float64(117), int64(1), object(1)
# memory usage: 2.6+ MB

# %%
miss
# Out:
#      Group        I1        I2        I3        I4        I5        I6  \
# 2      G10  0.104791 -0.038188 -0.053191  0.620233  0.148587  0.489875
# 3       G2 -0.532847 -0.006582 -0.023377  1.306702 -0.068909  0.048024
# 8       G7 -0.821333 -0.039547  0.008143 -0.759509 -0.303122 -0.378398
# 10      G1 -0.448898 -0.032152 -0.046113 -0.385375  0.240720 -0.104108
# 11      G2 -0.176154 -0.002824 -0.019954  0.500028 -0.255117  0.092953
# ...    ...       ...       ...       ...       ...       ...       ...
# 7988    G4  1.850844 -0.022288 -0.048949  0.353616 -0.270113 -0.064790
# 7992    G1 -0.947461 -0.039530 -0.051671       NaN  2.655020  0.131037
# 7995    G1 -0.946477 -0.039767 -0.051916       NaN -9.099326  1.470616
# 7998    G4  1.084416 -0.028497 -0.047528 -0.180118 -0.634162  0.143589
# 7999    G2  0.373261 -0.030294 -0.042319  0.675851 -0.099477 -0.113594
#
#             I7        I8        I9  ...      dI51      dI52      dI53  \
# ...

# %%
miss.Class.hist()
# Out:
# <AxesSubplot:>

# %%
training_data.Class.hist()
# Out:
# <AxesSubplot:>

# %%
training_data.describe()
# Out:
#                 I1           I2           I3           I4           I5  \
# count  8000.000000  8000.000000  8000.000000  7475.000000  7995.000000
# mean      0.073392    -0.013688    -0.021178     0.005549    -0.012115
# std       0.905966     0.182037     0.199068     0.948536     0.986441
# min      -2.432857    -0.076729    -0.060811    -1.038730   -15.806570
# 25%      -0.591216    -0.036932    -0.046093    -0.568159    -0.192743
# 50%      -0.141608    -0.029587    -0.038679    -0.247530    -0.077468
# 75%       0.489964    -0.017655    -0.027411     0.290979     0.075142
# max       5.013767     9.338686     9.323656    10.504271    22.755955
#
#                 I6           I7           I8           I9          I10  ...  \
# count  7999.000000  8000.000000  8000.000000  8000.000000  8000.000000  ...
# mean      0.022632     0.019241    -0.024724    -0.046254    -0.007465  ...
# std       0.958664     0.970220     0.225448     1.016823     0.195737  ...
# ...

# %%
training_data.median()
# Out:
# /var/folders/7y/57xm51hj4y11r4hg1s330bth0000gn/T/ipykernel_15461/3550620649.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   training_data.median()
# I1        -0.141608
# I2        -0.029587
# I3        -0.038679
# I4        -0.247530
# I5        -0.077468
#              ...
# dI56      -0.024760
# dI57       0.000374
# dI58       0.000889
# Class      0.000000
# Perform    0.027271
# Length: 118, dtype: float64
